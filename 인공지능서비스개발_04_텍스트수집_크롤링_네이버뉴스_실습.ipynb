# %% [markdown]
# # 1. 네이버 뉴스 Crawling with Naver Open API

# %%
# 네이버 검색 API 예제 -  블로그 검색 예제를 뉴스 검색 예제로 수정하여 실행
import os
import sys
import urllib.request
client_id = "yNtsqtpj1kGg4nHsvaTJ"
client_secret = "wThCv7r8yk"
encText = urllib.parse.quote("keyword")

url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 15:23:17 +0900",
# 	"total":320523,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"교체없는 해결법, 배관 막힘 바로잡기 {{<b>KEYWORD<\/b>_LIST}}",
# 			"link":"https:\/\/blog.naver.com\/elph5qjr0fq\/224141109404",
# 			"description":"교체없는 해결법, 배관 막힘 바로잡기 {{<b>KEYWORD<\/b>_LIST}} 요즘 싱크대가 자꾸 막혀서 설거지할 때마다... 초기 점검과 원인 파악 {{<b>KEYWORD<\/b>_LIST}} 먼저 하수구 업체는 막힌 원인을 찾고 상황에 맞는 장비로 다시 안... ",
# 			"bloggername":"화끈한수달",
# 			"bloggerlink":"blog.naver.com\/elph5qjr0fq",
# 			"postdate":"20260110"
# 		},
# 		{
# 			"title":"[IT <b>KEYWORD<\/b>] 온프레미스와 클라우드 사이, 기업은 왜... ",
# 			"link":"https:\/\/blog.naver.com\/lguplusbusiness\/224192623107",
# 			"description":"알아두면 쓸데 있는 IT <b>KEYWORD<\/b>! 또 다른 키워드들이 궁금하시다면? 아래 콘텐츠도 참고해 주세요! [IT <b>KEYWORD<\/b>] 창작부터 업무 자동화까지, 생성형 AI의 시대가 왔다 [IT <b>KEYWORD<\/b>] 모든 연결을 의심하라, 제로 트러스트... ",
# 			"bloggername":"LG U+ Enterprise",
# 			"bloggerlink":"blog.naver.com\/lguplusbusiness",
# 			"postdate":"20260223"
# 		},
# 		{
# 			"title":"Strategy is the new <b>keyword<\/b>: What drives paid search... ",
# 			"link":"https:\/\/searchengineland.com\/strategy-new-keyword-paid-search-performance-473398",
# 			"description":"new <b>keyword<\/b>: What drives paid search performance now Published: April 3, 2026 at 10:00 am... Over the course of my three-decade career, the <b>keyword<\/b> drove paid search. Today, it’s one... ",
# 			"bloggername":"Search Engine Land - News, Search Engine Optimization (SEO), Pay-Per-Click (PPC)",
# 			"bloggerlink":"https:\/\/searchengineland.com\/",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"{{PLACE}} 리모델링 꿀팁, {{<b>KEYWORD<\/b>_LIST}}로 시작하는 실전... ",
# 			"link":"https:\/\/blog.naver.com\/ruia85btl2mwt\/224185957565",
# 			"description":"{{<b>KEYWORD<\/b>_LIST}}로 시작하는 상담 사례 첫 상담에서 자세히 물어보니까요 대표님이 처음부터 끝까지... {{<b>KEYWORD<\/b>_LIST}} 기반 공정 설명 현장에 들어가기 전부터 공정 순서와 책임자를 명확히 알려주신 점이... ",
# 			"bloggername":"깨진올빼미",
# 			"bloggerlink":"blog.naver.com\/ruia85btl2mwt",
# 			"postdate":"20260217"
# 		},
# 		{
# 			"title":"Python에서 <b>keyword<\/b> 인자 처리 방식",
# 			"link":"https:\/\/blog.naver.com\/msyang59\/223827050529",
# 			"description":"Python에서 <b>keyword<\/b> 인자를 처리하는 방식에 있어 널리 사용되고 있는 방법으로 디폴트 파라미터 방식: func(*args, key=DEFAUT_VALUE, **kwargs)와 kwargs.pop 방식: key = kwargs.pop('key', DEFAULT_VALUE) 이렇게 두 가지... ",
# 			"bloggername":"過客의 블로그",
# 			"bloggerlink":"blog.naver.com\/msyang59",
# 			"postdate":"20250409"
# 		},
# 		{
# 			"title":"크리스마스 이브 업데이트: <b>Keyword<\/b> &amp; Search Term Quality",
# 			"link":"https:\/\/blog.naver.com\/amzbopyo\/224121919937",
# 			"description":"크리스마스 이브 업데이트: <b>Keyword<\/b> &amp; Search Term Quality SellerVisor Ads Management에 새로 추가된 기능은 <b>Keyword<\/b> &amp; Search Term Quality 입니다. 한 문장으로 정리하면, “잘 되는 키워드\/검색어”와 “광고비만... ",
# 			"bloggername":"보표의 한계없는 성장",
# 			"bloggerlink":"blog.naver.com\/amzbopyo",
# 			"postdate":"20251225"
# 		},
# 		{
# 			"title":"[VOICE TREND] 한 눈에 보는 24년 3월 HOT <b>Keyword<\/b> Overview",
# 			"link":"https:\/\/blog.naver.com\/playd_log\/223406491431",
# 			"description":"이번 원화 약세로 인해 소비자물가는 다시 위협받을 것으로 풀이됩니다 #금융키워드 #금융업종트렌드 #비트코인 #삼성전자주가 #환율 한 눈에 보는 24년 3월 Hot <b>Keyword<\/b> Overview 3월에는 여행\/교통, 화장품... ",
# 			"bloggername":"AI 마케팅 파트너 플레이디",
# 			"bloggerlink":"blog.naver.com\/playd_log",
# 			"postdate":"20240405"
# 		},
# 		{
# 			"title":"숏폼처럼 트렌디한 {sitle_title}의 {sitle_<b>keyword<\/b>} 최신... ",
# 			"link":"https:\/\/blog.naver.com\/souse20\/224239634293",
# 			"description":"숏폼처럼 트렌디한 {sitle_title}의 {sitle_<b>keyword<\/b>} 최신 공략집! 요즘 유튜브 숏폼만큼 빠르게 변하는 것이... {sitle_<b>keyword<\/b>}의 핵심, 다양한 치료사 직업 들여다보기 치료사라고 하면 막연하게 생각할 수 있지만, 사실... ",
# 			"bloggername":"마사지구인구직-채용정보",
# 			"bloggerlink":"blog.naver.com\/souse20",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"[참고문헌 검색] 논문 찾는 법 _키워드(<b>keyword<\/b>), 리뷰... ",
# 			"link":"https:\/\/blog.naver.com\/privatalab\/224178886355",
# 			"description":"키워드(<b>Keyword<\/b>) 자료 조사의 첫 단추는 검색창이 아니라 빈 종이 위에서 시작되어야 한다. 내가 강조하는 '키워드 맵'은 내 연구 주제를 입체적으로 분해하는 과정이다. &quot;키워드 한두 개면 충분하지... ",
# 			"bloggername":"논문\/연구 R&D.",
# 			"bloggerlink":"blog.naver.com\/privatalab",
# 			"postdate":"20260210"
# 		},
# 		{
# 			"title":"[송파미술학원] 고2 기초디자인 핵심 <b>keyword<\/b>!! - 송파... ",
# 			"link":"https:\/\/blog.naver.com\/designnext1\/223501598563",
# 			"description":"[송파미술학원] 고2 기초디자인 핵심 <b>keyword<\/b>!! - 송파 잠실미술학원 넥스트미술학원 #송파미술학원 고2 #기초디자인 핵심 <b>keyword<\/b>!! 송파 #잠실미술학원 #넥스트미술학원 안녕하세요! #송파입시미술 의 정상!!!... ",
# 			"bloggername":"송파 넥스트미술학원",
# 			"bloggerlink":"blog.naver.com\/designnext1",
# 			"postdate":"20240704"
# 		}
# 	]
# }

# %%
# 네이버 검색 API 예제 기반으로 네이버 검색 API 동작 방식 확인 (검색 결과 모두 받기)
# rescode가 200인 동안 start를 증가시켜서 계속 검색 (테스트를 위해 start는 25이하로 제한)
# 네이버 검색 API 예제 -  블로그 검색 예제를 뉴스 검색 예제로 수정하여 실행
import os
import sys
import urllib.request
client_id = "yNtsqtpj1kGg4nHsvaTJ"
client_secret = "wThCv7r8yk"
encText = urllib.parse.quote("인공지능")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과

start = 1
display = 10
rescode = 200
while rescode == 200 and start <100:
    
    new_url = url + f'&start={start}&display={display}'
    request = urllib.request.Request(new_url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        print(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)
    start +=display
# Out:
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 14:57:50 +0900",
# 	"total":3891906,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"컴퓨터학원 실용적인 <b>인공지능<\/b> 수업과정",
# 			"link":"https:\/\/blog.naver.com\/foryou1035\/224160610941",
# 			"description":"요즘 <b>인공지능<\/b>이 화두인데요. 처음에는 똑똑한 기능에 신기함이 컸지만, 시간이 갈수록 미묘한 감정이... 현재는 직장에서 <b>인공지능<\/b> 교육을 담당하게 되었고, 퇴근 후에는 취미로 웹사이트를 만들고 있어요.... ",
# 			"bloggername":"Ssong Story ♡",
# 			"bloggerlink":"blog.naver.com\/foryou1035",
# 			"postdate":"20260126"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 자격증 취득과정 및 취업 정보 정리",
# 			"link":"https:\/\/blog.naver.com\/gustlr00\/224087574160",
# 			"description":"<b>인공지능<\/b> 자격증 취득과정 및 취업 정보 정리 “AI를 이해하는 사람과 그렇지 못한 사람의 차이가 점점 더 커지고 있다&quot;라는 말을 실감하게 되는 요즘, 직장 내에서도, 취업 시장에서도 <b>인공지능<\/b> 기술을 다룰... ",
# 			"bloggername":"〃다시 만나는 그날 까지 〃",
# 			"bloggerlink":"blog.naver.com\/gustlr00",
# 			"postdate":"20251125"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b>전문가 자격증 취득과정 정리",
# 			"link":"https:\/\/blog.naver.com\/anycall2502\/224076021636",
# 			"description":"<b>인공지능<\/b>전문가 자격증 취득과정 정리 최근 <b>인공지능<\/b> 기술이 눈에 띄게 발전하고 있다는 걸 느끼면서 뒤처지면 안 되겠다는 생각이 들었어요. 주변에서는 AI 활용이 기본 역량처럼 자리 잡고 있는데, 정작... ",
# 			"bloggername":"더불어 사는 세상 이도형",
# 			"bloggerlink":"blog.naver.com\/anycall2502",
# 			"postdate":"20251114"
# 		},
# 		{
# 			"title":"학점은행제 <b>인공지능<\/b> 학위로 AI회사에 이직 성공했어요.",
# 			"link":"https:\/\/blog.naver.com\/seo8810603\/224226152116",
# 			"description":"저는 학점은행제 <b>인공지능<\/b> 학위로 이직까지 성공하게 된 30대 박ㅇ우입니다. 요즘 워낙 AI 기술이 많이... 솔직히 저도 처음에는 <b>인공지능<\/b>의 발전을 그렇게 달갑게 생각하진 않았어요. 사람의 일자리를... ",
# 			"bloggername":"Seo's reptile and Water life story",
# 			"bloggerlink":"blog.naver.com\/seo8810603",
# 			"postdate":"20260323"
# 		},
# 		{
# 			"title":"숙명여대 편입, <b>인공지능<\/b>공학부 합격까지 인서울 도전기",
# 			"link":"https:\/\/blog.naver.com\/spoly001\/224114522439",
# 			"description":"최근 IT와 AI 분야의 인재 양성에 주력하며 <b>인공지능<\/b>공학부를 신설해 미래 산업을 이끌어갈 여성 공학인 양성에 앞장서고 있습니다. 오늘은 실제로 숙명여대 <b>인공지능<\/b>공학부 편입에 성공한 학생의 생생한... ",
# 			"bloggername":"TV조선캠퍼스평생교육원 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/spoly001",
# 			"postdate":"20251218"
# 		},
# 		{
# 			"title":"엘지 LG 통돌이 세탁기 추천 용량 17kg <b>인공지능<\/b> T17WX3",
# 			"link":"https:\/\/blog.naver.com\/reser45\/224246855986",
# 			"description":"기술의 발전은 여기서 그치지 않고 <b>인공지능<\/b> AI과 결합되었습니다. LG 통돌이 세탁기에 넣은 빨랫감의 무게는 물론이고 소재의 특성까지 스스로 감지하여 최적의 물살 세기와 모션, 시간을 설정해 준다는 점이... ",
# 			"bloggername":"무스미엘",
# 			"bloggerlink":"blog.naver.com\/reser45",
# 			"postdate":"20260409"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 교육 AI교육 키트 언플러그드 코딩 주미AI",
# 			"link":"https:\/\/blog.naver.com\/alley1980\/224229641240",
# 			"description":"<b>인공지능<\/b> 교육 AI교육 키트 언플러그드 코딩 주미AI 어느덧 따스한 바람이 부는 새학기 시즌이라 아이들 교육 문제로 고민이 많은 시기지요. 요즘은 학교 수업에서도 <b>인공지능<\/b> 교육 비중이 커지다 보니 집에서도... ",
# 			"bloggername":"고고씨네 소소한 일상",
# 			"bloggerlink":"blog.naver.com\/alley1980",
# 			"postdate":"20260325"
# 		},
# 		{
# 			"title":"[연수기록] <b>인공지능<\/b> 맞춤형 교수학습 플랫폼(AIEP) 전달연수",
# 			"link":"https:\/\/blog.naver.com\/dndus3356\/224196778376",
# 			"description":"<b>인공지능<\/b> 맞춤형 교수학습 플랫폼(AIEP) 전남 - 아이모두 학교 담당자 전달연수 홍혜민 선생님 지역별로... AIEP = <b>인공지능<\/b> 맞춤형 교수학습 플랫폼 작년에 전남교육청에서 이 플랫폼의 이름을 공모했던 기억이... ",
# 			"bloggername":"우연샘의 꿈꾸는 교실",
# 			"bloggerlink":"blog.naver.com\/dndus3356",
# 			"postdate":"20260226"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 자격증 취득방법 총정리",
# 			"link":"https:\/\/blog.naver.com\/wwevoszmffjq\/224063279444",
# 			"description":"<b>인공지능<\/b> 자격증 취득방법 총정리 그래픽 디자인을 전공하고 5년 동안 근무했던 회사에서 <b>인공지능<\/b> 자격증이 없다며 잘렸어요. 창작 관련 분야는 AI와 상관없을 줄 알았는데, ' AI 그림 ', ' 이미지 생성 도구... ",
# 			"bloggername":"왜 안 가인요?",
# 			"bloggerlink":"blog.naver.com\/wwevoszmffjq",
# 			"postdate":"20251103"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b>(AI) 시대, 앞으로 일자리는 어떻게 변할까요?",
# 			"link":"https:\/\/blog.naver.com\/molab_suda\/224242653040",
# 			"description":"- ｢APEC 미래 일자리 포럼: <b>인공지능<\/b>(AI)와 인구구조 변화｣ 개최 - 산업전환 고용안정 기본계획... 이덕만 포스코 지능화센터장은 기존 수작업으로 진행하던 용광로 작업을, 데이터를 학습해 스스로 규칙을... ",
# 			"bloggername":"고용노동부 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/molab_suda",
# 			"postdate":"20260406"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 14:57:50 +0900",
# 	"total":3891905,
# 	"start":11,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"경기 용인 냉동 창고 시설 <b>인공지능<\/b> CCTV 설치 후기",
# 			"link":"https:\/\/blog.naver.com\/xavisnet\/224220577252",
# 			"description":"경기 용인 냉동 창고 시설 <b>인공지능<\/b> CCTV 설치 후기 안녕하세요, 자비스넷입니다. 오늘은 경기 용인에 위치한 냉동창고 현장에 <b>인공지능<\/b> 적외선 CCTV 4대를 설치한 후기를 공유해드릴게요. 냉동창고나... ",
# 			"bloggername":"XAVISnet",
# 			"bloggerlink":"blog.naver.com\/xavisnet",
# 			"postdate":"20260318"
# 		},
# 		{
# 			"title":"생성형 <b>인공지능<\/b> 뜻, 챗지피티·제미나이·클라우드 모델 비교",
# 			"link":"https:\/\/blog.naver.com\/teamlinchpin\/224177479277",
# 			"description":"생성형 <b>인공지능<\/b> 뜻, 챗지피티·제미나이·클라우드 모델 비교 요즘 뉴스, 업무, 공부, 콘텐츠 제작까지 어디를 가도 빠지지 않고 등장하는 단어가 있습니다. 바로 '생성형 <b>인공지능<\/b>(AI)'인데요. &quot;AI가 사람처럼... ",
# 			"bloggername":"온라인마케팅, 린치핀기획",
# 			"bloggerlink":"blog.naver.com\/teamlinchpin",
# 			"postdate":"20260209"
# 		},
# 		{
# 			"title":"AI학원, <b>인공지능<\/b> 전문가로 성장하는 가장 빠른 방법",
# 			"link":"https:\/\/blog.naver.com\/himediacokr\/224231103099",
# 			"description":"최근 AI 대전환이라 느껴질 만큼 우리 주변의 모든 산업이 <b>인공지능<\/b>을 중심으로 재편되고 있습니다. 챗... ✔️ 실전 모델 구현 인간의 뇌를 닮은 모델을 구축하는, 딥러닝과 인공신경망에 대해 배우게 됩니다.... ",
# 			"bloggername":"하이미디어 아카데미 공식블로그",
# 			"bloggerlink":"blog.naver.com\/himediacokr",
# 			"postdate":"20260327"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b>전문가 자격증 취득방법 총정리",
# 			"link":"https:\/\/blog.naver.com\/gustlr00\/224076037551",
# 			"description":"<b>인공지능<\/b>전문가 자격증 취득방법 총정리 요즘 AI 관련 뉴스가 하루가 다르게 쏟아지다 보니까, 저도 이... 그래서 장기적인 커리어 준비 차원에서 <b>인공지능<\/b>전문가 자격증 과정을 본격적으로 찾아보기... ",
# 			"bloggername":"〃다시 만나는 그날 까지 〃",
# 			"bloggerlink":"blog.naver.com\/gustlr00",
# 			"postdate":"20251114"
# 		},
# 		{
# 			"title":"학점은행제 <b>인공지능<\/b>, 학위 따고 재취업 성공(비전공자)",
# 			"link":"https:\/\/blog.naver.com\/jje423\/224228420448",
# 			"description":"학점은행제 <b>인공지능<\/b>, 학위 따고 재취업 성공(비전공자) 안녕하세요! 4년제 대학을 졸업하고도 전공... 그러다 우리 일상 곳곳에 스며든 <b>인공지능<\/b>(AI) 분야를 보며 &quot;지금이라도 이 길을 준비하면 늦지 않을까?... ",
# 			"bloggername":"욕심많은 별들맘 이야기",
# 			"bloggerlink":"blog.naver.com\/jje423",
# 			"postdate":"20260325"
# 		},
# 		{
# 			"title":"직장인 Ai 활용 능력 기르는 <b>인공지능<\/b> 학사학위",
# 			"link":"https:\/\/blog.naver.com\/seo8810603\/224224382865",
# 			"description":"과정으로 <b>인공지능<\/b> 공학으로 4년제 학사학위를 취득했어요. 온라인으로 학벌을 개선하는 이 방식이... 제가 준비한 학점은행제 <b>인공지능<\/b>학은 학교 출석업싱 온라인 과정으로 진행됐어요. 저는 4년제 대학을... ",
# 			"bloggername":"Seo's reptile and Water life story",
# 			"bloggerlink":"blog.naver.com\/seo8810603",
# 			"postdate":"20260321"
# 		},
# 		{
# 			"title":"몰트북 충격 읽어보니 AI 시대 얼마나 바뀔까 <b>인공지능<\/b> 책 추천",
# 			"link":"https:\/\/blog.naver.com\/limhyunae\/224248225786",
# 			"description":"몰트북 충격 읽어보니 AI 시대 얼마나 바뀔까 <b>인공지능<\/b> 책 추천 요즘 뉴스나 유튜브를 보다 보면 AI, <b>인공지능<\/b> 이야기가 빠지지 않고 등장하는 것 같아요. 단순히 기술 발전 정도가 아니라 우리삶 자체가... ",
# 			"bloggername":"달달한 그녀의 일상",
# 			"bloggerlink":"blog.naver.com\/limhyunae",
# 			"postdate":"20260410"
# 		},
# 		{
# 			"title":"학점은행제 <b>인공지능<\/b> 온라인으로 학위 취득했어요",
# 			"link":"https:\/\/blog.naver.com\/reebbang\/224181846192",
# 			"description":"저는 비전공자로 직장 생활을 하다가 미래를 위해 학점은행제 <b>인공지능<\/b> 전공을 통해 학사학위를 취득했던 20대 남성입니다. 처음에는 솔직히 <b>인공지능<\/b>이라는 단어가 너무 막연하게 느껴졌습니다. &quot;AI가... ",
# 			"bloggername":"30's Mood",
# 			"bloggerlink":"blog.naver.com\/reebbang",
# 			"postdate":"20260213"
# 		},
# 		{
# 			"title":"최소한의 수학』 <b>인공지능<\/b>을 이해하는 가장 현실적인 방법",
# 			"link":"https:\/\/blog.naver.com\/sandhya\/224206770826",
# 			"description":"AI가 쉬워지는 최소한의 수학 이동준2026지상의책(갈매나무) 사람들은 <b>인공지능<\/b>을 이야기할 때 종종... <b>인공지능<\/b>은 요술 상자처럼 느껴지기도 한다. 질문을 던지면 답을 내놓고, 사진을 보여주면 내용을 설명하고... ",
# 			"bloggername":"밀크티 책세상",
# 			"bloggerlink":"blog.naver.com\/sandhya",
# 			"postdate":"20260306"
# 		},
# 		{
# 			"title":"NVIDIA GTC 2026에서 본 <b>인공지능<\/b> 반도체의 미래! GPU, HBM... ",
# 			"link":"https:\/\/blog.naver.com\/nststory2014\/224251065664",
# 			"description":"<b>인공지능<\/b> 기술은 단순한 알고리즘 경쟁을 넘어, 실제 구현과 운영을 포함한 인프라 경쟁으로... 특히 이번 행사에서는 고대역폭메모리(HBM)와 GPU를 포함한 <b>인공지능<\/b> 반도체가 데이터 처리와 추론 성능을... ",
# 			"bloggername":"국가과학기술연구회",
# 			"bloggerlink":"blog.naver.com\/nststory2014",
# 			"postdate":"20260414"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 14:57:50 +0900",
# 	"total":3891905,
# 	"start":21,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"[고용노동부] 지청 <b>인공지능<\/b>(AI) 활용 교육",
# 			"link":"https:\/\/blog.naver.com\/ahnbh334\/224200193453",
# 			"description":"이번 강의에서는 지청장님의 특별한 관심과 배려 속에 <b>인공지능<\/b>에 대한 운영현황과 발전방향에 대하여 소개했는데 정부의 <b>인공지능<\/b>에 대한 발전 정책 때문인지 공무원들의 관심 또한 민간 못지않게... ",
# 			"bloggername":"KPMC 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/ahnbh334",
# 			"postdate":"20260301"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b>이 내 마음을 읽는다? 허스키렌즈2로 감정 인식 실습하기",
# 			"link":"https:\/\/blog.naver.com\/icbanq\/224244999842",
# 			"description":"최근 <b>인공지능<\/b> 기술이 비약적으로 발전하면서, 단순히 사물을 식별하는 것을 넘어 카메라 하나로... 오늘은 허스키렌즈2를 활용해 사람의 마음을 읽는 <b>인공지능<\/b> 실습을 진행해 보았습니다! 이 기술은... ",
# 			"bloggername":"No.1 반도체·산업용컴퓨터·피지컬AI 전문몰",
# 			"bloggerlink":"blog.naver.com\/icbanq",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b>(AI)로 진화하는 산재보험...근로복지공단 ’K... ",
# 			"link":"https:\/\/blog.naver.com\/molab_suda\/224229343408",
# 			"description":"- 대한민국 <b>인공지능<\/b>(AI) 10대 선도기관 선정, 클라우드 네이티브 전환 우수사례 인정 - <b>인공지능<\/b>(AI)재해조사·치료예측·장해판정·일자리추천...산재보험 <b>인공지능<\/b>(AI) 전환 본격화 근로복지공단(이사장... ",
# 			"bloggername":"고용노동부 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/molab_suda",
# 			"postdate":"20260325"
# 		},
# 		{
# 			"title":"'만화로 배우는 AI <b>인공지능<\/b>' 소개 및 후기",
# 			"link":"https:\/\/blog.naver.com\/whruddlf75\/224159351443",
# 			"description":"'만화로 배우는 AI <b>인공지능<\/b>' 소개 만화로 배우는 AI <b>인공지능<\/b> 미야케 요이치로.전승민 감수, 비젠 야스노리 그림, 신은주 옮김2023비전코리아 미야케 요이치로 지금 전승민 감수의 '만화로 배우는 AI... ",
# 			"bloggername":"혼노리",
# 			"bloggerlink":"blog.naver.com\/whruddlf75",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"AI가 위협하는 직업은 무엇일까 #<b>인공지능<\/b>일자리",
# 			"link":"https:\/\/blog.naver.com\/eterna01\/224219200381",
# 			"description":"최근 몇 년 동안 <b>인공지능<\/b>(AI)은 우리의 일과 직업 세계를 빠르게 바꾸고 있습니다. 특히 챗봇... 오늘의 핵심 영어 단어 20개 Artificial Intelligence – <b>인공지능<\/b> Threatened – 위협받는 Adapt – 적응하다... ",
# 			"bloggername":"Jer 29:11",
# 			"bloggerlink":"blog.naver.com\/eterna01",
# 			"postdate":"20260317"
# 		},
# 		{
# 			"title":"거짓을 찾아내는 <b>인공지능<\/b>의 눈, 딥페이크탐지기술의 진화",
# 			"link":"https:\/\/blog.naver.com\/himediacokr\/224244149299",
# 			"description":"기계는 흉내 낼 수 없는, 생체 신호 분석 아무리 딥페이크 영상이 눈으로 보기에 완벽해도, <b>인공지능<\/b>이... 알고리즘이 남긴 보이지 않는 흔적 모든 <b>인공지능<\/b> 모델은 영상을 생성할 때 자신만의 독특한 디지털... ",
# 			"bloggername":"하이미디어 아카데미 공식블로그",
# 			"bloggerlink":"blog.naver.com\/himediacokr",
# 			"postdate":"20260407"
# 		},
# 		{
# 			"title":"안전은 높이고! 부산시 <b>인공지능<\/b>(AI) 기반 교통관리시스템 도입",
# 			"link":"https:\/\/blog.naver.com\/cooolbusan\/224227464918",
# 			"description":"부산광역시(시장 박형준)는 시민이 일상에서 직접 체감하는 교통 편의를 높이기 위해 <b>인공지능<\/b>(AI)과 교통데이터를 접목한 지능형 교통 신호체계 고도화를 본격적으로 추진합니다. 번 사업은 스마트빌리지... ",
# 			"bloggername":"부산광역시 대표 블로그",
# 			"bloggerlink":"blog.naver.com\/cooolbusan",
# 			"postdate":"20260324"
# 		},
# 		{
# 			"title":"AI교육 <b>인공지능<\/b> 활용능력에 대하여",
# 			"link":"https:\/\/blog.naver.com\/ljshhj\/224147887778",
# 			"description":"본 포스팅은 업체로부터 원고료를 받아 작성되었습니다 AI교육 <b>인공지능<\/b> 활용능력에 대하여 AI, <b>인공지능<\/b>은 챗지피티처럼 질문하고 답변하는 걸 넘어서 사진이나 영상 등을 합성하고 업무를 도와줄 만큼... ",
# 			"bloggername":"떠나자닷컴",
# 			"bloggerlink":"blog.naver.com\/ljshhj",
# 			"postdate":"20260115"
# 		},
# 		{
# 			"title":"[챗지피티 교육] &quot;생성형 <b>인공지능<\/b> 활용, 프롬프트 및 보고서... ",
# 			"link":"https:\/\/blog.naver.com\/hijunggon\/224240732080",
# 			"description":"세종특별자치시교육청의 지방공무원분들을 대상으로 '생성형 <b>인공지능<\/b>(ChatGPT) 활용, 프롬프트 및... 본 과정은 챗지피티(ChatGPT)를 비롯한 다양한 생성형 <b>인공지능<\/b> 도구의 활용법을 학습하여 실제 업무에... ",
# 			"bloggername":"김정곤의 강연노트",
# 			"bloggerlink":"blog.naver.com\/hijunggon",
# 			"postdate":"20260404"
# 		},
# 		{
# 			"title":"국립광주과학관 [2026 전국민 <b>인공지능<\/b>(AI) 창작 경진대회] 안내",
# 			"link":"https:\/\/blog.naver.com\/sciencenter\/224231614689",
# 			"description":"참가분야 <b>인공지능<\/b> 창작 도구를 활용한 그림 및 로고송 접수기간 4. 20.(월) ~ 6. 30.(화), 18:00 접수방법 참가신청서 및 동의서, 작품(그림 또는 음원) 파일제출 후원 한국지능정보사회진흥원(NIA) 문의처... ",
# 			"bloggername":"국립광주과학관님의 블로그",
# 			"bloggerlink":"blog.naver.com\/sciencenter",
# 			"postdate":"20260331"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 14:57:50 +0900",
# 	"total":3891905,
# 	"start":31,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"발달장애 학생을 위한 맞춤형 <b>인공지능<\/b>(AI) 학습 시대 열린다",
# 			"link":"https:\/\/blog.naver.com\/moeblog\/224212332128",
# 			"description":"교육부, 발달장애 학생의 학습 특성을 고려한 ‘<b>인공지능<\/b>(AI)·디지털 교육자료’ 신학기 본격 보급 첨부파일 [교육부 03-12(목) 조간보도자료] 발달장애 학생을 위한 맞춤형 <b>인공지능<\/b>(AI) 학습 시대 열린다.pdf... ",
# 			"bloggername":"교육부",
# 			"bloggerlink":"blog.naver.com\/moeblog",
# 			"postdate":"20260311"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 데이터센터와, 속도를 만드는 메모리 반도체",
# 			"link":"https:\/\/blog.naver.com\/with_msip\/224163789021",
# 			"description":"<b>인공지능<\/b>은 기존 IT 서버보다 더 많은 연산을 요구합니다. 기존 컴퓨팅 기술처럼 계산만 하는 것이... 메모리의 성능이 곧 <b>인공지능<\/b>의 성능과 인프라 개선으로 이어진다는 사실 알고 계셨나요? 금만큼 귀해진... ",
# 			"bloggername":"과학기술정보통신부 블로그",
# 			"bloggerlink":"blog.naver.com\/with_msip",
# 			"postdate":"20260204"
# 		},
# 		{
# 			"title":"챗GPT강사 김진희 한국전력공사 생성형AI(<b>인공지능<\/b>) 공기업... ",
# 			"link":"https:\/\/blog.naver.com\/steady_jinhee\/224246992382",
# 			"description":"챗GPT강사 김진희 한국전력공사 생성형AI(<b>인공지능<\/b>) 공기업 실무교육 특강 안녕하세요 :) 미래교육아카데미 대표이자, 한국강사교육협회 협회장, 챗GPT강사 김진희입니다. 2026년 생성형AI(<b>인공지능<\/b>)에 대한... ",
# 			"bloggername":"챗GPT강사 한국강사교육협회 대표 김진희",
# 			"bloggerlink":"blog.naver.com\/steady_jinhee",
# 			"postdate":"20260409"
# 		},
# 		{
# 			"title":"제자들은 자란다(<b>인공지능<\/b> 융합수업 가이드)",
# 			"link":"https:\/\/blog.naver.com\/odelmio\/224235370118",
# 			"description":"제자들은 자란다(<b>인공지능<\/b> 융합수업 가이드) 2026 03 31 화 학교에 있으면서 나이듦을 실감하기 시작하는... 오한나, &lt;<b>인공지능<\/b> 융합수업 가이드: 챗GPT, AIVA, 구글을 활용한 미래 음악 교실&gt;(다빈치북스, 2023)... ",
# 			"bloggername":"모르는 요셉",
# 			"bloggerlink":"blog.naver.com\/odelmio",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"해외선물  나스닥 100 지수 추종 AI 관련주 <b>인공지능<\/b> 테마... ",
# 			"link":"https:\/\/blog.naver.com\/bonodesign3\/224246208820",
# 			"description":"해외선물 나스닥 100 지수 추종 AI 관련주 <b>인공지능<\/b> 테마 종목 선택 1. 해외선물 나스닥100, <b>인공지능<\/b> 관련주 투자 시 주요 체크 사항 최근 투자자들 사이에서 미국 나스닥 시장에 상장된 <b>인공지능<\/b>(AI) 관련... ",
# 			"bloggername":"(주)몽플디자인센터",
# 			"bloggerlink":"blog.naver.com\/bonodesign3",
# 			"postdate":"20260409"
# 		},
# 		{
# 			"title":"[디지털캠프] <b>인공지능<\/b>(AI) 작곡 탐사대는 무슨 프로그램일까?",
# 			"link":"https:\/\/blog.naver.com\/dalkkum_plus\/224242871976",
# 			"description":"단연 '생성형 <b>인공지능<\/b>(AI)'입니다. 하지만 단순한 체험을 넘어, 학생들의 사고력을 확장하고 실제 결과물까지 도출할 수 있는 프로그램을 찾기는 쉽지 않습니다. 저희 디지털캠프 '<b>인공지능<\/b>(AI) 작곡 탐사대는... ",
# 			"bloggername":"달꿈 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/dalkkum_plus",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 시대, 우리는 노예가 될 것인가 주인이 될 것인가... ",
# 			"link":"https:\/\/blog.naver.com\/pencilvase\/224246977296",
# 			"description":"&lt;이어령의 말&gt; 이어령 지음_세계사_초판 1쇄 2025년 2월 26일 지능의 노예가 될 거인가 확장의 주인이 될 것인가? <b>인공지능<\/b>이라는 말(馬)에 올라타는 법 1990년대 후반 우리는 '정보의 바다'라고 불리는 거대한 파도와... ",
# 			"bloggername":"연필꽂이하루일기",
# 			"bloggerlink":"blog.naver.com\/pencilvase",
# 			"postdate":"20260409"
# 		},
# 		{
# 			"title":"AI 국부론 책 후기 AGI 뜻 약자 영어줄임말 (범용<b>인공지능<\/b>)",
# 			"link":"https:\/\/blog.naver.com\/babydreamer5\/224221388090",
# 			"description":"특정 작업 하나만 잘하는 <b>인공지능<\/b>이 아니라, 인간처럼 여러 문제를 폭넓게 이해하고 새로운 상황에도 적용할 수 있는 지능을 뜻해요. 사실 지금의 많은 AI는 번역, 요약, 이미지 생성, 검색 보조처럼 특정... ",
# 			"bloggername":"영어뉴스와 미드영어",
# 			"bloggerlink":"blog.naver.com\/babydreamer5",
# 			"postdate":"20260318"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 시대의 게임 체인저, AI전문트랙의 가치",
# 			"link":"https:\/\/blog.naver.com\/himediacokr\/224234669618",
# 			"description":"단순한 코딩 능력이 아닌, 데이터에서 인사이트를 추출하고 이를 기반으로 <b>인공지능<\/b> 모델을 설계 및... ✔️ 딥러닝 및 신경망 최적화 인간의 뇌 구조를 모사한 인공신경망의 원리를 배우고, 텐서플로나... ",
# 			"bloggername":"하이미디어 아카데미 공식블로그",
# 			"bloggerlink":"blog.naver.com\/himediacokr",
# 			"postdate":"20260330"
# 		},
# 		{
# 			"title":"공교육에 <b>인공지능<\/b> 교육이 필요한 이유",
# 			"link":"https:\/\/blog.naver.com\/hamamath_\/224218126842",
# 			"description":"공교육에 <b>인공지능<\/b> 교육이 필요한 이유 교육부 AI 교육 확대 정책이 시사하는 변화 교육부가 초·중등 <b>인공지능<\/b> 교육 담당 교원 역량 강화 연수 과정을 개발하고 본격적인 운영에 들어간다는 발표는 단순한... ",
# 			"bloggername":"수학문해력",
# 			"bloggerlink":"blog.naver.com\/hamamath_",
# 			"postdate":"20260316"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 14:57:50 +0900",
# 	"total":3891905,
# 	"start":41,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"머신러닝전문가 교육정보 <b>인공지능<\/b>융합학과에서 공부해요",
# 			"link":"https:\/\/blog.naver.com\/ocublog\/224192322874",
# 			"description":"머신러닝은 데이터를 기반으로 <b>인공지능<\/b> 모델을 설계하고 학습, 배포 등을 하는 직업인 만큼 미래... 머신러닝 전문가가 되기 위한 과정을 밟을 수 있는 <b>인공지능<\/b>융합학과를 소개해 드립니다. 머신러닝에... ",
# 			"bloggername":"일과 학업을 동시에! 한국열린사이버대학교!",
# 			"bloggerlink":"blog.naver.com\/ocublog",
# 			"postdate":"20260223"
# 		},
# 		{
# 			"title":"[ChatGPT 교육] &quot;생성형 <b>인공지능<\/b>(AI) 업무 활용법(기본 과정... ",
# 			"link":"https:\/\/blog.naver.com\/hijunggon\/224250271948",
# 			"description":"대전시설관리공단 임직원분들을 대상으로 '생성형 <b>인공지능<\/b>(AI) 업무 활용법(기본 과정)'에 관한 주제로 2일 동안 실습 강의를 했습니다. 본 과정은 챗지피티(ChatGPT)를 비롯한 다양한 생성형 <b>인공지능<\/b> 도구의... ",
# 			"bloggername":"김정곤의 강연노트",
# 			"bloggerlink":"blog.naver.com\/hijunggon",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"우리 노동부의 <b>인공지능<\/b>(AI) 혁신을 앞당기는 공무원 개발자... ",
# 			"link":"https:\/\/blog.naver.com\/molab_suda\/224246562694",
# 			"description":"총 40팀이 참여할 수 있는 행사에 116팀이 지원하며 <b>인공지능<\/b>(AI) 학습과 현장 적용에 대한 노동부 직원의 뜨거운 관심을 확인할 수 있었습니다. 이날 행사는 <b>인공지능<\/b>(AI) 노동법 상담, 노동감독 <b>인공지능<\/b>(AI)... ",
# 			"bloggername":"고용노동부 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/molab_suda",
# 			"postdate":"20260409"
# 		},
# 		{
# 			"title":"교육부, 초·중등 <b>인공지능<\/b> 교육 담당교원을 위한 연수과정... ",
# 			"link":"https:\/\/blog.naver.com\/moeblog\/224218006604",
# 			"description":"초등 교원, 중등 정보, 고교 ‘<b>인공지능<\/b> 수학’ 교과 담당 교원을 위한 맞춤형 <b>인공지능<\/b> 교육 연수 체계 구축 기초-심화-전문 단계 멀티트랙 구조로 2026년 5월 기초 단계 연수 시작, 2029년까지 1만 명 이수... ",
# 			"bloggername":"교육부",
# 			"bloggerlink":"blog.naver.com\/moeblog",
# 			"postdate":"20260316"
# 		},
# 		{
# 			"title":"[육아일기] 경북교육청 발명<b>인공지능<\/b>교육원",
# 			"link":"https:\/\/blog.naver.com\/zz_anna\/224232565522",
# 			"description":"#따빛샘 #육아일기 경주 황리단길 한복판에 위치한:) #경상북도 #발명<b>인공지능<\/b>교육원 원래... #발명<b>인공지능<\/b>교육원 주관 부스6개 #메이커교육관 부스 2개 #<b>인공지능<\/b>교육관 부스 3개 표정으로 인형뽑기와 AI와... ",
# 			"bloggername":"따빛의 일기장",
# 			"bloggerlink":"blog.naver.com\/zz_anna",
# 			"postdate":"20260328"
# 		},
# 		{
# 			"title":"[현장한컷] <b>인공지능<\/b> 혁신기업 현장 방문",
# 			"link":"https:\/\/blog.naver.com\/ppspr\/224235764773",
# 			"description":"<b>인공지능<\/b>(AI) 재활용 선별 로봇, <b>인공지능<\/b> 사물인터넷(AIoT) 스마트 안심 화장실 등 혁신기술 현장 방문  혁신제품 시범구매·글로벌 실증 지원을 통해 딥테크 기업 성장 가속화 강성민 조달청 차장은 3월 31일... ",
# 			"bloggername":"조달청 블로그",
# 			"bloggerlink":"blog.naver.com\/ppspr",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"[민간자격] <b>인공지능<\/b>(AI) 활용 블랙벨트",
# 			"link":"https:\/\/blog.naver.com\/ahnbh334\/224213227765",
# 			"description":"최근 전 세계적으로 <b>인공지능<\/b>(AI)에 대한 관심이 빠르게 확산되고 있습니다. 개인의 업무 생산성... 2일 16시간 집중 커리큘럼 따라서 KPMC는 이달 3월 21~22일(주말과정), 진행하는 &quot;<b>인공지능<\/b>(AI) 활용 블랙벨트... ",
# 			"bloggername":"KPMC 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/ahnbh334",
# 			"postdate":"20260312"
# 		},
# 		{
# 			"title":"성남시 AI 중점학교 목록 (<b>인공지능<\/b> 중점학교 목록)",
# 			"link":"https:\/\/blog.naver.com\/jamduino\/224243884597",
# 			"description":"AI 중점학교는 일반 학교보다 정보 교과 수업 시수를 대폭 늘려 <b>인공지능<\/b> 교육을 체계적으로 운영하는... <b>인공지능<\/b>, 정보 교육을 강화하면서 학교별 특색을 반영한 AI 교육 활동을 운영합니다. 정규교육과정... ",
# 			"bloggername":"실적을 만드는 코딩학원 잼코딩학원",
# 			"bloggerlink":"blog.naver.com\/jamduino",
# 			"postdate":"20260407"
# 		},
# 		{
# 			"title":"경상북도교육청발명<b>인공지능<\/b>교육원 개원식 현장",
# 			"link":"https:\/\/blog.naver.com\/2mcool\/224250377007",
# 			"description":"나를 분석하는 똑똑한 <b>인공지능<\/b> • B 발명<b>인공지능<\/b>교육원 • B-1 360도 퓨처캠 : 발명 쇼츠 스튜디오 나만의 360도 영상, SNS에 공유하고 '인생 숏츠' 주인공 되자! 안전상의 이유로 바닥에 설치된 원판 위에 서서... ",
# 			"bloggername":"경상북도교육청",
# 			"bloggerlink":"blog.naver.com\/2mcool",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"바둑 로봇 AI <b>인공지능<\/b> 바둑판 세트 이런 분께 추천",
# 			"link":"https:\/\/blog.naver.com\/sjrnfl81\/224206852844",
# 			"description":"AI <b>인공지능<\/b> 바둑로봇이라니, 처음엔 어떻게 작동하는지 궁금하더라고요. 요즘 바둑 학습 도구로... AI <b>인공지능<\/b> 바둑로봇, 어떤 제품인가요? AI <b>인공지능<\/b> 바둑로봇은 사람 대신 바둑을 두어주는 스마트 바둑판... ",
# 			"bloggername":"또 다른 세상",
# 			"bloggerlink":"blog.naver.com\/sjrnfl81",
# 			"postdate":"20260306"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 14:57:50 +0900",
# 	"total":3891905,
# 	"start":51,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"[486] <b>인공지능<\/b>시대 철학수업 (박시몽)",
# 			"link":"https:\/\/blog.naver.com\/jckwb66\/224236464116",
# 			"description":"답을 찾고자 하면 깊이 생각하기 보다는 <b>인공지능<\/b>에게 질문하는 횟수들이 늘어나다보니 스스로 오래... 질문으로 답을 찾는 <b>인공지능<\/b> 시대 철학 수업 박시몽2026한언 철학이란 어렵게만 느껴지지만 샘은... ",
# 			"bloggername":"백여샘의 진로이야기",
# 			"bloggerlink":"blog.naver.com\/jckwb66",
# 			"postdate":"20260401"
# 		},
# 		{
# 			"title":"캠코, <b>인공지능<\/b>(AI)과 증강현실(AR)을 활용한 스마트 국유재산... ",
# 			"link":"https:\/\/blog.naver.com\/blogkamco\/224243924694",
# 			"description":"위해 ‘<b>인공지능<\/b> 기반 항공영상 변화탐지 시스템’과 ‘증강현실 기반 모바일 실태조사 시스템’... 먼저, <b>인공지능<\/b>기반 항공영상 변화탐지 시스템은 서로 다른 시기에 촬영된 항공영상을 자동으로 비교... ",
# 			"bloggername":"캠코(한국자산관리공사) 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/blogkamco",
# 			"postdate":"20260407"
# 		},
# 		{
# 			"title":"AI책 추천 슈퍼휴먼 슈퍼워크 <b>인공지능<\/b> 시대 일하는 법",
# 			"link":"https:\/\/blog.naver.com\/limhyunae\/224222765253",
# 			"description":"슈퍼워크 <b>인공지능<\/b> 시대 일하는 법 최근 AI 관련 책을 찾다가 읽게 된 슈퍼휴먼 슈퍼워크는 단순한 AI 활용법을 넘어 앞으로어떻게 일해야 하는가를 생각하게 만든 책이었어요. 요즘 AI책이나 <b>인공지능<\/b>책이... ",
# 			"bloggername":"달달한 그녀의 일상",
# 			"bloggerlink":"blog.naver.com\/limhyunae",
# 			"postdate":"20260319"
# 		},
# 		{
# 			"title":"[책을펴다] AI로 미래를 설계하는 서울<b>인공지능<\/b>고등학교",
# 			"link":"https:\/\/blog.naver.com\/seouledu2012\/224242405941",
# 			"description":"3월의 책을 펴다는 AI로 미래를 설계하는 '서울<b>인공지능<\/b>고등학교'에서 시작합니다. 혼자 읽던 이야기가... 미디어 콘텐츠 AI 프롬프트 디자인 &quot;AI콘텐츠디자인과인 저에게, <b>인공지능<\/b>을 활용한 콘텐츠 제작의... ",
# 			"bloggername":"서울교육블로그",
# 			"bloggerlink":"blog.naver.com\/seouledu2012",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"돋보인다? 기업 블로그 마케팅 이제 <b>인공지능<\/b> 자동화할까?",
# 			"link":"https:\/\/blog.naver.com\/akinterv\/224247369008",
# 			"description":"강의 팔이 들 뿐 아니라, 딱 봐도 영향력 전혀 없는 사람들도 자신이 <b>인공지능<\/b> 자동화로 수익을 크게... 생성형 <b>인공지능<\/b>, 말 그대로 복사하는 것이 아니라 주제만 주면 새로운 콘텐츠를 생성하는 거다. 그런데... ",
# 			"bloggername":"The Life, Marketing stories through photos",
# 			"bloggerlink":"blog.naver.com\/akinterv",
# 			"postdate":"20260410"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 전환의 파도를 타다! 2026 K-ICT WEEK in BUSAN... ",
# 			"link":"https:\/\/blog.naver.com\/cooolbusan\/224243637056",
# 			"description":"<b>인공지능<\/b> 전환(AX)의 흐름을 선도하기 위해, 지역 최대 규모의 ICT 종합 행사인 2026 K-ICT WEEK in BUSAN에 참여할 역량 있는 기업들을 오는 4월 13일부터 본격적으로 모집합니다. 이번 행사는 <b>인공지능<\/b> 코리아... ",
# 			"bloggername":"부산광역시 대표 블로그",
# 			"bloggerlink":"blog.naver.com\/cooolbusan",
# 			"postdate":"20260407"
# 		},
# 		{
# 			"title":"첨단산업 인재양성 부트캠프로 <b>인공지능<\/b>(AI) 융합인재를... ",
# 			"link":"https:\/\/blog.naver.com\/moeblog\/224235510761",
# 			"description":"첨단산업 인재양성 부트캠프 운영대학 중 <b>인공지능<\/b>(AI) 융합과정을 운영할 10개교 선정 반도체, 바이오 등 첨단분야(X) 문제를 <b>인공지능<\/b>(AI)으로 해결하는 <b>인공지능<\/b> 융합형(AI+X) 인재 양성 첨부파일 [교육부 04... ",
# 			"bloggername":"교육부",
# 			"bloggerlink":"blog.naver.com\/moeblog",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"AIEP (<b>인공지능<\/b> 맞춤형 교수학습 플랫폼) 웨일 스페이스 이용... ",
# 			"link":"https:\/\/blog.naver.com\/whaleteam\/224220723730",
# 			"description":"안녕하세요, 네이버 웨일팀입니다  2026년 신학기부터 일부 교육청에서 운영 중인 AIEP(<b>인공지능<\/b>... AIEP (<b>인공지능<\/b> 맞춤형 교수학습 플랫폼) 네이버 웨일 스페이스 활용 안내 첨부파일 [네이버] AIEP 웨일... ",
# 			"bloggername":"네이버 웨일",
# 			"bloggerlink":"blog.naver.com\/whaleteam",
# 			"postdate":"20260318"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 키트 커서AI 코마크레 코딩키트 후기",
# 			"link":"https:\/\/blog.naver.com\/em2868\/224181947315",
# 			"description":"<b>인공지능<\/b> 키트 커서AI 코마크레 코딩키트 후기 글.사진#start 요즘 아이와 집에서 할 수 있는 교육 키트를... <b>인공지능<\/b> 키트 코딩키트는 온라인 강의와 함께 스스로 만들어가는 코딩키트라는 점이 제가 못받아본... ",
# 			"bloggername":"라이프 아카이브",
# 			"bloggerlink":"blog.naver.com\/em2868",
# 			"postdate":"20260212"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b>(AI)을 활용한 안전보건 영상 제작",
# 			"link":"https:\/\/blog.naver.com\/ahnbh334\/224218963591",
# 			"description":"<b>인공지능<\/b>(AI)을 활용한 안전보건 영상 제작 과정을 올해 두 번째로 진행했습니다. 온라인(Zoom)과... 교육의 목적 이번 교육은 <b>인공지능<\/b> 도구를 활용해 안전보건 영상을 스스로 기획하고 제작할 수 있도록 돕는 데... ",
# 			"bloggername":"KPMC 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/ahnbh334",
# 			"postdate":"20260317"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 14:57:50 +0900",
# 	"total":3891905,
# 	"start":61,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"제8회 교육 공공데이터 <b>인공지능<\/b>(AI) 활용대회 3월 16일부터... ",
# 			"link":"https:\/\/blog.naver.com\/moeblog\/224212361833",
# 			"description":"교육 공공데이터와 <b>인공지능<\/b>(AI) 기술의 융합으로 미래교육을 위한 혁신 아이디어 발굴 총 154팀... ※ 전년도(제7회) 대상 수상작 (학생부, 분석분야) 통학로 안전 지수 시각화 및 지능형 폐쇄회로 시시티브이... ",
# 			"bloggername":"교육부",
# 			"bloggerlink":"blog.naver.com\/moeblog",
# 			"postdate":"20260311"
# 		},
# 		{
# 			"title":"교육부, <b>인공지능<\/b> 시대 융합인재 양성 ‘융합교육(STEAM)... ",
# 			"link":"https:\/\/blog.naver.com\/moeblog\/224235512945",
# 			"description":"운영 <b>인공지능<\/b> 등 미래 과학기술 기반 융합교육(STEAM) 동아리 확대로, 학교 현장의 융합교육 본격화 【관련 국정과제】 99-1. <b>인공지능<\/b> 디지털 시대 미래인재 양성 첨부파일 [교육부 04-01(수) 조간보도자료]... ",
# 			"bloggername":"교육부",
# 			"bloggerlink":"blog.naver.com\/moeblog",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"‘이제 키오스크, <b>인공지능<\/b>(AI)도 두렵지 않아요’ 생활 밀착형... ",
# 			"link":"https:\/\/blog.naver.com\/moeblog\/224245703009",
# 			"description":"찾아가는 <b>인공지능<\/b>(AI)·디지털 문해교육 ‘한글햇살버스’ 10개 지역 본격 출범 전국 174개... 키오스크, <b>인공지능<\/b>도 두렵지 않아요 생활 밀착형 성인 문해교육 지원 강화.pdf 교육부(장관 최교진)와... ",
# 			"bloggername":"교육부",
# 			"bloggerlink":"blog.naver.com\/moeblog",
# 			"postdate":"20260409"
# 		},
# 		{
# 			"title":"교육부-두산연강재단, <b>인공지능<\/b> 교육을 이끄는 정보 교원의... ",
# 			"link":"https:\/\/blog.naver.com\/moeblog\/224250393512",
# 			"description":"교육부-두산연강재단 <b>인공지능<\/b> 교육을 이끄는 정보 교원의 성장 지원.pdf 교육부(장관 최교진)와... <b>인공지능<\/b> 교육이 확대되고 교과 간 융합 교육이 강조되는 상황에서, 정보 교원과 수학 교원이 함께하는... ",
# 			"bloggername":"교육부",
# 			"bloggerlink":"blog.naver.com\/moeblog",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 기반 한국어교육 시스템 ‘모두의 한국어’ 단계적... ",
# 			"link":"https:\/\/blog.naver.com\/moeblog\/224245015478",
# 			"description":"제공, <b>인공지능<\/b> 튜터, 한국어 퀴즈, 단어장 등 학생회원에게만 제공하던 기능을 일반회원에게도 제공... 교육격차 해소를 위한 공교육 강화 첨부파일 [교육부 04-09(목) 조간보도자료] <b>인공지능<\/b> 기반... ",
# 			"bloggername":"교육부",
# 			"bloggerlink":"blog.naver.com\/moeblog",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b>으로 여는 치유농업의 미래, 산업화·창업 전략 모색",
# 			"link":"https:\/\/blog.naver.com\/nihhs\/224242982571",
# 			"description":"협력… <b>인공지능<\/b> 기반 치유 산업 확대 방안 논의 농촌진흥청(청장 이승돈)은 (사)한국도시농업연구회와 함께 4월 9일 부산광역시 농업기술센터에서 ‘<b>인공지능<\/b> 기반 치유 산업화와 창업 모형 전략’을... ",
# 			"bloggername":"국립원예특작과학원",
# 			"bloggerlink":"blog.naver.com\/nihhs",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"[두산 연강원] <b>인공지능<\/b>(AI) 강의",
# 			"link":"https:\/\/blog.naver.com\/ahnbh334\/224199233117",
# 			"description":"학습자들이 <b>인공지능<\/b>이라는 다소 새로운 주제에 몰입하기에 최적의 공간이었습니다. 멋진 테이블 구조와 공간구조 이번 <b>인공지능<\/b> 교육은 단순 강의가 아닌 실습 중심 참여형 교육으로 진행되었기 때문에... ",
# 			"bloggername":"KPMC 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/ahnbh334",
# 			"postdate":"20260228"
# 		},
# 		{
# 			"title":"[보도자료] <b>인공지능<\/b> 사회로의 혁신 전환을 위한 해법 찾는다",
# 			"link":"https:\/\/blog.naver.com\/pipcpr\/224251697580",
# 			"description":"<b>인공지능<\/b> 사회로의 혁신 전환을 위한 해법 찾는다 - 개인정보위, 연구모임 ‘개인정보 AX 엔진룸’ 본격 가동(4.10.) - 전문가 강연 및 자발적 논의 통한 <b>인공지능<\/b>전환(AX) 혁신 방안 설계 개인정보보호위원회... ",
# 			"bloggername":"개인정보보호위원회(개인정보위)",
# 			"bloggerlink":"blog.naver.com\/pipcpr",
# 			"postdate":"20260414"
# 		},
# 		{
# 			"title":"2026년 2+3월호(제366호) 특집기획1: 생성형 <b>인공지능<\/b> 학습과... ",
# 			"link":"https:\/\/blog.naver.com\/kcc_press\/224250696323",
# 			"description":"특집기획1 생성형 <b>인공지능<\/b> 학습과 저작권, 균형을 잡다 글 _ 한효정 한국저작권위원회 선임연구원... 생성형 <b>인공지능<\/b>(Generative Artificial Intelligence, 이하 GAI)이 우리의 일상과 산업 전반에 깊숙이 자리 잡으면서... ",
# 			"bloggername":"한국저작권위원회",
# 			"bloggerlink":"blog.naver.com\/kcc_press",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"피지컬 <b>인공지능<\/b>이 바꾸는 미래 모빌리티 시트의 진화",
# 			"link":"https:\/\/blog.naver.com\/hyundai-transys\/224231189149",
# 			"description":"① 사람의 몸과 직접 맞닿는 <b>인공지능<\/b>: 화면 너머의 지능이 아닌, 시트와 조작계 등 실물 영역에서 탑승자의 자세와 움직임을 실시간 감지하여 상호작용합니다. ② 끊임없는 데이터의 축적과 반복 생성... ",
# 			"bloggername":"현대트랜시스",
# 			"bloggerlink":"blog.naver.com\/hyundai-transys",
# 			"postdate":"20260327"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 14:57:51 +0900",
# 	"total":3891905,
# 	"start":71,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"모든 것을 식별하는 <b>인공지능<\/b>의 눈, YOLO",
# 			"link":"https:\/\/blog.naver.com\/himediacokr\/224238589429",
# 			"description":"덕분에 <b>인공지능<\/b>은 실시간 영상에서도 끊김 없이 사물을 추적할 수 있게 되었습니다. 객체인식 기술이 바꿀 우리의 미래 앞으로 YOLO 기술은 우리의 삶을 더 안전하고 편리하게 바꿔줄 겁니다. ✔️ 지능형... ",
# 			"bloggername":"하이미디어 아카데미 공식블로그",
# 			"bloggerlink":"blog.naver.com\/himediacokr",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"외국인 건설근로자, 퇴직공제금 신청 ‘<b>인공지능<\/b>(AI)로 해결’",
# 			"link":"https:\/\/blog.naver.com\/molab_suda\/224250675405",
# 			"description":"이번 서비스는 <b>인공지능<\/b>(AI) 기술을 활용하여 다양한 언어를 실시간으로 통·번역해 주는 서비스로, 외국인 방문 민원이 많은 공제회 서울남부센터와 경기지사에 전용 창구를 마련하여 개시하였습니다. 이번... ",
# 			"bloggername":"고용노동부 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/molab_suda",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"교육부, 초·중등 <b>인공지능<\/b> 교육을 이끄는 ‘<b>인공지능<\/b>(AI)... ",
# 			"link":"https:\/\/blog.naver.com\/moeblog\/224209725312",
# 			"description":"<b>인공지능<\/b> 교육을 종합적으로 추진하는 <b>인공지능<\/b>(AI) 중점학교 선정 완료 및 본격 운영 올해 17개 시도교육청 1,141개교 선정, 2028년까지 단계적 확대 추진 【관련 국정과제】 99-1. <b>인공지능<\/b> 디지털 시대... ",
# 			"bloggername":"교육부",
# 			"bloggerlink":"blog.naver.com\/moeblog",
# 			"postdate":"20260309"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b>은 정말 공정한가? 의료·금융 등에서 ‘편향성 적발’",
# 			"link":"https:\/\/blog.naver.com\/siencia\/224205095183",
# 			"description":"<b>인공지능<\/b>(AI) 알고리즘에 의해 주택 대출 승인, 취업 면접 기회, 병원 응급실 우선 치료 같은 중요한... <b>인공지능<\/b>, 이미 사람의 중요한 선택을 결정하고 있다 오늘날 AI 알고리즘은 많은 사람들의 삶에 영향을... ",
# 			"bloggername":"전파과학사",
# 			"bloggerlink":"blog.naver.com\/siencia",
# 			"postdate":"20260309"
# 		},
# 		{
# 			"title":"몰트북 충격  <b>인공지능<\/b> 에이전트 정의와 활용법",
# 			"link":"https:\/\/blog.naver.com\/coin116\/224234507029",
# 			"description":"제미나이 <b>인공지능<\/b>이 연동되면서 사용자의 의도와 다른 문자 발송으로 논란이 되었던 적 있었다. 사용자의 의도를 다르게 해석하여 곤란한 상황에 빠뜨리는 <b>인공지능<\/b> 활용 사례를 보면서 <b>인공지능<\/b>에게 과도한... ",
# 			"bloggername":"쓴다주의 배우고 읽는 기록장",
# 			"bloggerlink":"blog.naver.com\/coin116",
# 			"postdate":"20260330"
# 		},
# 		{
# 			"title":"서부초, 교실 속 <b>인공지능<\/b> 교육 혁신 공유",
# 			"link":"https:\/\/blog.naver.com\/us_edu\/224249574373",
# 			"description":"서부초는 6일 <b>인공지능<\/b>·디지털 교육 동구 권역 학교 교사들과 함께 전문적 학습공동체 다모임을 열었다 - 동구 권역 5개 초등학교 참여, <b>인공지능<\/b>·디지털 교육 협력체계 확대 울산 동구 서부초등학교(교장... ",
# 			"bloggername":"울산광역시교육청",
# 			"bloggerlink":"blog.naver.com\/us_edu",
# 			"postdate":"20260412"
# 		},
# 		{
# 			"title":"[책 추천] 질문으로 답을 찾는 <b>인공지능<\/b>시대 철학수업",
# 			"link":"https:\/\/blog.naver.com\/sinbisu\/224231710995",
# 			"description":"질문으로 답을 찾는 <b>인공지능<\/b> 시대 철학 수업 박시몽2026한언 <b>인공지능<\/b> 시대에 새롭게 떠오른 철학적 질문들을, 철학자와의 대화를 통해 풀어가는 재미있고 신선한 철학 책입니다. 고등학교 윤리교사이신... ",
# 			"bloggername":"Ordinary Days",
# 			"bloggerlink":"blog.naver.com\/sinbisu",
# 			"postdate":"20260327"
# 		},
# 		{
# 			"title":"<b>인공 지능<\/b> QA를 활용한다면",
# 			"link":"https:\/\/blog.naver.com\/ymkim1959\/224188112123",
# 			"description":"자동화 가능성 높음 70% 정확도 향상 100% <b>인공지능<\/b>으로 80% 효율 향상 3) 이를 구현하는 방법은? 예 : 지능형 문서 검토 및 승인 현재 프로세스 : DHF, DMR 문서다 30-60분의 수동 검토, 체크리스트... ",
# 			"bloggername":"의료기기 연구원들이 기준규격을 모두 익힐때까지",
# 			"bloggerlink":"blog.naver.com\/ymkim1959",
# 			"postdate":"20260219"
# 		},
# 		{
# 			"title":"[디지털캠프] 용인중학교를 뒤흔든 <b>인공지능<\/b> 드로잉 탐사대 현장!",
# 			"link":"https:\/\/blog.naver.com\/dalkkum_plus\/224239832942",
# 			"description":"바로 1학년부터 3학년까지 전교생이 함께한 '<b>인공지능<\/b>(AI) 드로잉 탐사대' 현장인데요! 평소 교실과는... 넘어, <b>인공지능<\/b>을 도구로 삼아 아이들의 상상력을 시각화하는 창의 융합 교육으로 꾸며졌습니다. ✅ 쉽고... ",
# 			"bloggername":"달꿈 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/dalkkum_plus",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"사회초년생에게 <b>인공지능<\/b>(AI)이 위협적인 이유",
# 			"link":"https:\/\/blog.naver.com\/kihasa1970\/224242919371",
# 			"description":"이상이 <b>인공지능<\/b>(AI) 노출도가 높은 업종이었다는 통계를 봤어요. 실제 신입 채용이 줄어드는 부분이... #<b>인공지능<\/b> #AI #청년일자리 #쉬었음 #청년정책 #전국청년정책네트워크 #김지선 #뽀라 #팟캐스트",
# 			"bloggername":"한국보건사회연구원 공식블로그",
# 			"bloggerlink":"blog.naver.com\/kihasa1970",
# 			"postdate":"20260406"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 14:57:51 +0900",
# 	"total":3891905,
# 	"start":81,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"송메이커로 배우는 <b>인공지능<\/b> 수업 이야기",
# 			"link":"https:\/\/blog.naver.com\/jaya1216\/224248797282",
# 			"description":"안녕하세요  초등학생들과 함께 **크롬의 송메이커**를 활용해 <b>인공지능<\/b> 개념을 재미있게... AI 개념 연결하기 “컴퓨터도 규칙을 배우면 음악을 만들 수 있어요” → <b>인공지능<\/b>이 패턴을 학습한다는 개념... ",
# 			"bloggername":"아이들과 함께 배우는 코딩쌤",
# 			"bloggerlink":"blog.naver.com\/jaya1216",
# 			"postdate":"20260411"
# 		},
# 		{
# 			"title":"◐ <b>인공지능<\/b>(AI) 여성 로봇과 탈현대와의 상관 관계",
# 			"link":"https:\/\/blog.naver.com\/bhjang3\/224231186561",
# 			"description":"◐ <b>인공지능<\/b>(AI) 여성 로봇과 탈현대와의 상관 관계 “<b>인공지능<\/b>(AI) 여성 로봇”과 “탈현대”와의... 이 점에서 AI 여성 로봇은 현대의 경계들, 즉 인간\/기계, 자연\/인공, 주체\/객체의 경계를 흐리는 탈현대적... ",
# 			"bloggername":"德 田 의 문 화 일 기.",
# 			"bloggerlink":"blog.naver.com\/bhjang3",
# 			"postdate":"20260327"
# 		},
# 		{
# 			"title":"2026학년도 서울<b>인공지능<\/b>고등학교 학부모총회 개최",
# 			"link":"https:\/\/blog.naver.com\/ysth_news\/224229470625",
# 			"description":"함께 소통하며 만들어가는 학생들의 미래 2026년 3월 25일(수), 서울<b>인공지능<\/b>고등학교에서는 2026학년도... 이어 교장 선생님의 인사말에서는 서울<b>인공지능<\/b>고등학교의 교육 방향이 제시되었습니다. 교장... ",
# 			"bloggername":"서인고 꿈이루미",
# 			"bloggerlink":"blog.naver.com\/ysth_news",
# 			"postdate":"20260325"
# 		},
# 		{
# 			"title":"그록AI <b>인공지능<\/b> 서비스..유료 전환",
# 			"link":"https:\/\/blog.naver.com\/happycj88\/224231352372",
# 			"description":"#그록AI유료화 #그록서비스유료전환 #유료<b>인공지능<\/b>서비스 이웃님들 안녕하세요 오늘은 오후에 블로그 소식 전해봅니다. 요즘 <b>인공지능<\/b> 앱들 많이 쓰고 있는데 그중 최근에 그록AI가 유료화로 바뀌었어요. 며칠전... ",
# 			"bloggername":"정라이프의 온라인 창작소",
# 			"bloggerlink":"blog.naver.com\/happycj88",
# 			"postdate":"20260327"
# 		},
# 		{
# 			"title":"질문으로 답을 찾는 <b>인공지능<\/b>시대 철학 수업 \/ 박시몽",
# 			"link":"https:\/\/blog.naver.com\/foredu0813\/224233684985",
# 			"description":"질문으로 답을 찾는 <b>인공지능<\/b>시대 철학 수업 \/ 박시몽 질문으로 답을 찾는 <b>인공지능<\/b> 시대 철학 수업 박시몽2026한언 책을 쓰면서 알게 된 윤리 교사 박시몽 선생님께서 책 선물을 보내 주셨습니다. 국어 교사의... ",
# 			"bloggername":"국어 교사 보득솔쌤 이승우쌤 국어 수업",
# 			"bloggerlink":"blog.naver.com\/foredu0813",
# 			"postdate":"20260329"
# 		},
# 		{
# 			"title":"알고리즘 작곡 <b>인공 지능<\/b> 작사",
# 			"link":"https:\/\/blog.naver.com\/mci9306\/224250524515",
# 			"description":"기계, 알고리즘, <b>인공지능<\/b> 모두 사람이 작동의 주체다. 랜섬웨어로 데이터를 몽땅 날렸을 때 정도와는 비교할 수는 없지만 머리에서 김이 난다. 그렇지만 성질내봐야 나만 손해이니 참기로 한다.",
# 			"bloggername":"Jahee Lee",
# 			"bloggerlink":"blog.naver.com\/mci9306",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b>(AI) 중점학교, 앞으로 어떻게 운영될까요?",
# 			"link":"https:\/\/blog.naver.com\/moeblog\/224210185351",
# 			"description":"초·중등 <b>인공지능<\/b> 교육을 이끌어 갑니다! <b>인공지능<\/b>(AI) 중점학교 운영! 초·중등학교에서 <b>인공지능<\/b> 교육을 체계적으로 확대하고 학교 현장의 <b>인공지능<\/b> 교육 모델을 확산하기 위해 전국 17개 시도의 총 1... ",
# 			"bloggername":"교육부",
# 			"bloggerlink":"blog.naver.com\/moeblog",
# 			"postdate":"20260309"
# 		},
# 		{
# 			"title":"&lt; <b>인공지능<\/b>은 새로운 수압 파쇄법일까요? &gt;",
# 			"link":"https:\/\/blog.naver.com\/milohoon\/224244499799",
# 			"description":"&lt; <b>인공지능<\/b>은 새로운 수압 파쇄법일까요? &gt; - 정보 센터(data centres)에 대한 반발은 과거 에너지... 그 이후 <b>인공지능<\/b>에 대한 반발이 거세지는 것을 보며 저는 그 대답이 긍정적이라고 생각하게 되었습니다.... ",
# 			"bloggername":"Giuni's",
# 			"bloggerlink":"blog.naver.com\/milohoon",
# 			"postdate":"20260407"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 아이 &lt;깡통소년&gt;",
# 			"link":"https:\/\/blog.naver.com\/32claudia\/224189834143",
# 			"description":"따라서 <b>인공지능<\/b>이 스스로 판단하는 시대에 우리에게 필요한 것은 단순히 고도화된 지능이 아니라, 콘라트가 부인을 위해 스스로 '불량품'이 되기를 선택하며 보여준 '사랑'과 '공감'이라는 인간 고유의 가치를... ",
# 			"bloggername":"미고의 독서정원",
# 			"bloggerlink":"blog.naver.com\/32claudia",
# 			"postdate":"20260220"
# 		},
# 		{
# 			"title":"안전하고 포용적인 <b>인공지능<\/b>(AI)·디지털 사회 실현을 위해 4개... ",
# 			"link":"https:\/\/blog.naver.com\/moeblog\/224229368864",
# 			"description":"있는 <b>인공지능<\/b>(AI) 활용기반 구축 등 공동 협력 추진 첨부파일 [교육부 03-26(목) 행사시작시(10시)보도자료] (관계부처합동) 안전하고 포용적인 <b>인공지능<\/b> 디지털 사회 실현을 위해 4개 기관이 앞장선다.pdf 교육부... ",
# 			"bloggername":"교육부",
# 			"bloggerlink":"blog.naver.com\/moeblog",
# 			"postdate":"20260326"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 14:57:51 +0900",
# 	"total":3891905,
# 	"start":91,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"강서구 <b>인공지능<\/b> 기업Pool 모집 안내",
# 			"link":"https:\/\/blog.naver.com\/gangseokkachi\/224161385742",
# 			"description":"강서구에서는 <b>인공지능<\/b> 기술을 보유한 기업과의 협력을 통해 스마트 행정과 미래 산업 기반을 강화하고자 「강서구 <b>인공지능<\/b> 기업Pool」을 모집합니다.  모집개요 ⏰ 모집기간  2026. 1. 21.(수) ~ 2. 1.(일)... ",
# 			"bloggername":"서울특별시 강서구청",
# 			"bloggerlink":"blog.naver.com\/gangseokkachi",
# 			"postdate":"20260127"
# 		},
# 		{
# 			"title":"이제는 <b>인공지능<\/b>이 지배하는 세상이..",
# 			"link":"https:\/\/blog.naver.com\/ds2npi\/224247660622",
# 			"description":"언론, 인터넷을 통해 하루가 멀다하고 나오는 <b>인공지능<\/b> 이야기를 하고 싶습니다. 이제는 병원에가서 의사에게 진료를 받다가도 AI 내용과 다르다며 처방전을 달리 요구하거나 본인의 증상을 자가진단하여 알고... ",
# 			"bloggername":"섭이의블로그입니다^^",
# 			"bloggerlink":"blog.naver.com\/ds2npi",
# 			"postdate":"20260410"
# 		},
# 		{
# 			"title":"AI G3의 기틀 「<b>인공지능<\/b>기본법」 1월 22일 시행",
# 			"link":"https:\/\/blog.naver.com\/with_msip\/224156215871",
# 			"description":"AI G3의 기틀인 「<b>인공지능<\/b>기본법」 1월 22일 시행 AI산업 진흥 기반을 조성하기 위한 '<b>인공지능<\/b>기본법'이 시행됩니다. 세계에서 두 번째로 제정된 '<b>인공지능<\/b>기본법'은 국가 <b>인공지능<\/b> 거버넌스를 법제화하고... ",
# 			"bloggername":"과학기술정보통신부 블로그",
# 			"bloggerlink":"blog.naver.com\/with_msip",
# 			"postdate":"20260122"
# 		},
# 		{
# 			"title":"[에디토리얼] <b>인공지능<\/b> 혁명기의 조경 설계",
# 			"link":"https:\/\/blog.naver.com\/la_korea\/224236690022",
# 			"description":"전문가의 경험과 방대한 데이터 속에 잠재된 공간지능을 명확하게 포착해 구조화하는 일이야말로 AI 혁명기의 도시설계와 조경이 나아갈 방향이다. 다섯 편의 글은 서로 다른 시선으로 <b>인공지능<\/b>을 바라보지만... ",
# 			"bloggername":"조경 문화 발전소를 꿈꾸는 환경과조경",
# 			"bloggerlink":"blog.naver.com\/la_korea",
# 			"postdate":"20260401"
# 		},
# 		{
# 			"title":"에너지 및 전력 시장의 <b>인공지능<\/b>(AI), 2031년 227억 달러 예측",
# 			"link":"https:\/\/blog.naver.com\/giikorea2\/224245133915",
# 			"description":"세계 에너지 및 전력 분야의 <b>인공지능<\/b>(AI) 시장은 연평균 25.1%의 성장률을 기록하며 2026년 74억 달러에서 2031년 227억 달러에 이를 것으로 전망됩니다. <b>인공지능<\/b>(AI)은 전 세계 에너지 시스템 전반에... ",
# 			"bloggername":"글로벌인포메이션 - Market Research Portal",
# 			"bloggerlink":"blog.naver.com\/giikorea2",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> RA를 활용한다면...",
# 			"link":"https:\/\/blog.naver.com\/ymkim1959\/224188055328",
# 			"description":"<b>인공지능<\/b> 활용 \/ AI Solution : 생성형 AI 초안 작성: GPT-4, Claude 등을 활용하여 제품 정보와 임상 데 이터를 기반으로 초안 자동 생성. 지능형 템플릿: 기기 등급 및 제출 국가에 따른 최적 템플릿 자동... ",
# 			"bloggername":"의료기기 연구원들이 기준규격을 모두 익힐때까지",
# 			"bloggerlink":"blog.naver.com\/ymkim1959",
# 			"postdate":"20260219"
# 		},
# 		{
# 			"title":"나도 이제 프로듀서! 더 완벽해진 ‘<b>인공지능<\/b> 작곡 탐사대’",
# 			"link":"https:\/\/blog.naver.com\/dalkkum_plus\/224247852026",
# 			"description":"바로 디지털캠프 - 코스웨어탐사대의 ‘<b>인공지능<\/b> 작곡 탐사대’ 입니다. 2026년을 맞아 <b>인공지능<\/b> 작곡 탐사대가 대대적인 기능 업데이트를 마쳤습니다. 이제 어떤 점들이 달라졌는지 하나씩 살펴볼까요? 1️⃣... ",
# 			"bloggername":"달꿈 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/dalkkum_plus",
# 			"postdate":"20260410"
# 		},
# 		{
# 			"title":"제작기간 단 48시간...<b>인공지능<\/b>으로 재탄생한 '곽거병' 일대기",
# 			"link":"https:\/\/blog.naver.com\/china_lab\/224223949392",
# 			"description":"<b>인공지능<\/b>(AI)으로 제작된 중국 단편 영화 '곽거병(霍去病)'이 공개 한 달 만에 온라인에서 선풍적인... 영화는 장대한 전투 장면뿐만 아니라 돌격 시 휘날리는 먼지, 긴장감 넘치는 군마의 울음소리, 주인공의... ",
# 			"bloggername":"CHINA LAB",
# 			"bloggerlink":"blog.naver.com\/china_lab",
# 			"postdate":"20260320"
# 		},
# 		{
# 			"title":"[생각연필 독서논술 4월 추천도서] 주제 : <b>인공지능<\/b>(AI)",
# 			"link":"https:\/\/blog.naver.com\/ahjahj1004\/224237117440",
# 			"description":"앞으로의 세상은 <b>인공지능<\/b>을 다룰 줄 아는 사람과 <b>인공지능<\/b>에 일자리를 빼앗기는 사람. 이 두 가지로 나뉠 거라는 말도 쉽게 듣는 세상이에요. 이젠 거부할 수 없는 시대의 물결이자 새로운... ",
# 			"bloggername":"글쓰는 엘리의 읽고 쓰는 날들",
# 			"bloggerlink":"blog.naver.com\/ahjahj1004",
# 			"postdate":"20260401"
# 		},
# 		{
# 			"title":"학성여자고, 수행평가 설계에 <b>인공지능<\/b> 활용",
# 			"link":"https:\/\/blog.naver.com\/us_edu\/224238378422",
# 			"description":"개발까지 <b>인공지능<\/b>을 활용하는 연구에 들어갔다. 이를 통해 성취 평가제 환경에서 과정 중심 평가를... “평가가 <b>인공지능<\/b>을 통해 학교생활기록부와 자연스럽게 연계돼, 학생 한 명 한 명에게 의미 있는 자산이... ",
# 			"bloggername":"울산광역시교육청",
# 			"bloggerlink":"blog.naver.com\/us_edu",
# 			"postdate":"20260402"
# 		}
# 	]
# }

# %% [markdown]
# # 2. NaverNewsCrawler 개발
# 1. 네이버 뉴스 API로 Crawling : **crawlNaverNews(keyword)** -> 파이썬 json 데이터
# 1. 응답데이터를 리스트에 저장 : **mergeResultToList(result_list, merged_list)** -> List
# 1. 응답데이터가 없을 때까지 반복
# 1. 리스트를 CSV 파일로 저장 : **saveJSONListToCSV(merged_list, csv_filename)**

# %%
# 검색 API 호출, 응답을 JSON 데이터로 return하는 함수 작성
# API 호출 결과에 문제가 있을 경우 exception으로 처리
# exception 발생 시 exception과 호출 url 확인 (try : ... except Exception as e: ... )
import os
import sys
import urllib.request
import json
import time

def crawlNaverNews(keyword, start, display=10):
    client_id = "yNtsqtpj1kGg4nHsvaTJ"
    client_secret = "wThCv7r8yk"
    encText = urllib.parse.quote(keyword)  # ← 따옴표 제거!
    url = "https://openapi.naver.com/v1/search/news?query=" + encText  # ← news로 변경!
    
    new_url = url + f'&start={start}&display={display}'
    request = urllib.request.Request(new_url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        json_data = response_body.decode('utf-8')
        py_data = json.loads(json_data)
        time.sleep(0.5)
        return py_data
    else:
        print("Error Code:" + str(rescode))
        return None

# %%
# 응답데이터를 리스트에 통합
def mergeResultToList(result_list, merged_list):
    for result in result_list:
        merged_list.append(result)

# %%
# JSON의 list를 dataframe으로 변환하여 csv 파일로 저장

# %%
keyword = '룰러'

# API 호출 결과 전송된 JSON이 없거나, 전송된 JSON이 빈 결과가 없을 때까지
# 검색 결과를 JSON의 list로 저장 후 검색 API 호출 호출

resultAll = []


start = 1
while start < 1000:
    crawled_data = crawlNaverNews(keyword, start)
    if crawled_data:
        #print(crawled_data)
        print('crawling 성공 :', start)
        resultAll += crawled_data['items']
        start += 10
    else:
        print('crawling 실패 :', start)
        break

#dictionary의 리스트
# Out:
# crawling 성공 : 1
# crawling 성공 : 11
# crawling 성공 : 21
# crawling 성공 : 31
# crawling 성공 : 41
# crawling 성공 : 51
# crawling 성공 : 61
# crawling 성공 : 71
# crawling 성공 : 81
# crawling 성공 : 91
# crawling 성공 : 101
# crawling 성공 : 111
# crawling 성공 : 121
# crawling 성공 : 131
# crawling 성공 : 141
# crawling 성공 : 151
# crawling 성공 : 161
# crawling 성공 : 171
# crawling 성공 : 181
# crawling 성공 : 191
# crawling 성공 : 201
# crawling 성공 : 211
# crawling 성공 : 221
# crawling 성공 : 231
# crawling 성공 : 241
# crawling 성공 : 251
# crawling 성공 : 261
# crawling 성공 : 271
# crawling 성공 : 281
# crawling 성공 : 291
# crawling 성공 : 301
# crawling 성공 : 311
# crawling 성공 : 321
# crawling 성공 : 331
# crawling 성공 : 341
# crawling 성공 : 351
# crawling 성공 : 361
# crawling 성공 : 371
# crawling 성공 : 381
# crawling 성공 : 391
# crawling 성공 : 401
# crawling 성공 : 411
# crawling 성공 : 421
# crawling 성공 : 431
# crawling 성공 : 441
# crawling 성공 : 451
# crawling 성공 : 461
# crawling 성공 : 471
# crawling 성공 : 481
# crawling 성공 : 491
# crawling 성공 : 501
# crawling 성공 : 511
# crawling 성공 : 521
# crawling 성공 : 531
# crawling 성공 : 541
# crawling 성공 : 551
# crawling 성공 : 561
# crawling 성공 : 571
# crawling 성공 : 581
# crawling 성공 : 591
# crawling 성공 : 601
# crawling 성공 : 611
# crawling 성공 : 621
# crawling 성공 : 631
# crawling 성공 : 641
# crawling 성공 : 651
# crawling 성공 : 661
# crawling 성공 : 671
# crawling 성공 : 681
# crawling 성공 : 691
# crawling 성공 : 701
# crawling 성공 : 711
# crawling 성공 : 721
# crawling 성공 : 731
# crawling 성공 : 741
# crawling 성공 : 751
# crawling 성공 : 761
# crawling 성공 : 771
# crawling 성공 : 781
# crawling 성공 : 791
# crawling 성공 : 801
# crawling 성공 : 811
# crawling 성공 : 821
# crawling 성공 : 831
# crawling 성공 : 841
# crawling 성공 : 851
# crawling 성공 : 861
# crawling 성공 : 871
# crawling 성공 : 881
# crawling 성공 : 891
# crawling 성공 : 901
# crawling 성공 : 911
# crawling 성공 : 921
# crawling 성공 : 931
# crawling 성공 : 941
# crawling 성공 : 951
# crawling 성공 : 961
# crawling 성공 : 971
# crawling 성공 : 981
# crawling 성공 : 991

# %%
resultAll[:2]
# Out:
# [{'title': '<b>룰러</b> 조세 회피 논란, 중소 리그 선수 겸직 취소로 번져',
#   'originallink': 'https://www.gamevu.co.kr/news/articleView.html?idxno=57225',
#   'link': 'https://www.gamevu.co.kr/news/articleView.html?idxno=57225',
#   'description': "4월과 함께 e스포츠 업계를 달구고 있는 젠지 '리그오브레전드' 프로게이머 <b>룰러</b> 박재혁의 조세 회피 논란이... 앞서 <b>룰러</b>는 매니저 인건비 처리와 주식 명의신탁 부분에 대해 조세 회피 목적이라고 보고 국세청으로부터... ",
#   'pubDate': 'Tue, 14 Apr 2026 11:38:00 +0900'},
#  {'title': '롤 스타플레이어 <b>룰러</b> 세금 논란에 페이커 소환한 젠지 팬들...무리수에...',
#   'originallink': 'http://www.newsworker.co.kr/news/articleView.html?idxno=421835',
#   'link': 'http://www.newsworker.co.kr/news/articleView.html?idxno=421835',
#   'description': '탈세 논란을 받는 프로게이머 <b>룰러</b> 박재혁 선수 이슈가 계속되는 가운데 일부 젠지e스포츠(젠지) 팬들이... 논란의 발단은 지난 3월 말 불거진 <b>룰러</b>의 탈세 의혹이다. 해당 사안과 관련해 국세청 판단에 불복한 사실까지... ',
#   'pubDate': 'Tue, 14 Apr 2026 11:32:00 +0900'}]

# %%
import pandas as pd
data_df = pd.DataFrame(resultAll)

# 파일명 변수 정의
result_filename = f'./data/{keyword}_navernews.csv'

# 파일 저장
data_df.to_csv(result_filename)
print(f'저장 완료: {result_filename}')
# Out:
# 저장 완료: ./data/룰러_navernews.csv

# %%
# 검색어 입력

keyword = '인공지능'


# API 호출 결과 전송된 JSON이 없거나, 전송된 JSON에 검색 결과가 없을 때까지
# 검색 결과를 JSON의 list로 저장 후 검색 API 추가 호출


# 검색 결과를 저장할 list 초기화
resultAll = []
#첫 검색 API 호출 데이터 초기화
start =1
display = 10
merged_list =[]
while true: 
      crawled_data = crawlNaverNews(keyword, start)
    # API 호출 성공 여부 출력
    if crawled_data :
        print(f'{keyword} [{start}] : 검색성공')
    else:
        print(f'{keyword} [{start}] : 검색실패')
        break
    # crawling된 데이터가 없으면 중지

    # 응답데이터 정리하여 리스트로 통합
      mergeResultToList(crawled_data, merged_list)
    # 다음 검색 API 호출을 위한 파라미터 조정
    start += display

# 리스트를 csv 파일로 저장
# Out:
#   File <string>:19
#     if crawled_data :
#                      ^
# IndentationError: unindent does not match any outer indentation level

# %%
# 저장한 파일을 dataframe으로 loading 해보기
loaded_data_df = pd.read_csv(result_filename, index_col=0)
loaded_data_df
# Out:
#                                                  title  \
# 0               <b>룰러</b> 조세 회피 논란, 중소 리그 선수 겸직 취소로 번져
# 1    롤 스타플레이어 <b>룰러</b> 세금 논란에 페이커 소환한 젠지 팬들...무리수에...
# 2                   잘못은 한 명이 했는데, 왜 네 명이 못 뛰나 [엑's 이슈]
# 3                          [LCK] 22차 젠지 북벌 성공한 디플러스 기아
# 4                          물고 물리는 혼전, 누구도 승리를 장담할 수 없다
# ..                                                 ...
# 995  [LCK 현장] 젠지 김정수 감독, &quot;29승 1패, 말도 안되는 성적&quot;
# 996  김정수 젠지 감독 &quot;29승 1패, 우리도 예상 못한 성적…선수들 고맙다&q...
# 997  [LCK] &quot;정규 시즌 29승 1패, 말도 안 되는 성적&quot; 소감 ...
# 998       젠지 김정수 “PO 준비? ‘이런 것도 연습하네’ 싶을 정도로” [쿠키 현...
# 999    [LCK] ‘새터데이 쇼다운 승자’ 젠지, T1 PO 2R ‘좌절’…한화생명 어...
#
#                                           originallink  \
# 0    https://www.gamevu.co.kr/news/articleView.html...
# 1    http://www.newsworker.co.kr/news/articleView.h...
# 2           https://www.xportsnews.com/article/2136228
# 3                       https://game.donga.com/122196/
# 4    https://www.gameshot.net/common/con_view.php?c...
# ..                                                 ...
# 995  https://www.gamevu.co.kr/news/articleView.html...
# 996  https://www.dailian.co.kr/news/view/1542415/?s...
# 997  https://www.inven.co.kr/webzine/news/?news=309007
# 998  https://www.kukinews.com/article/view/kuk20250...
# 999          http://www.osen.co.kr/article/G1112646025
#
#                                                   link  \
# 0    https://www.gamevu.co.kr/news/articleView.html...
# 1    http://www.newsworker.co.kr/news/articleView.h...
# 2    https://m.sports.naver.com/esports/article/311...
# 3                       https://game.donga.com/122196/
# 4    https://www.gameshot.net/common/con_view.php?c...
# ..                                                 ...
# 995  https://www.gamevu.co.kr/news/articleView.html...
# 996  https://n.news.naver.com/mnews/article/119/000...
# 997  https://m.sports.naver.com/esports/article/442...
# 998  https://www.kukinews.com/article/view/kuk20250...
# 999  https://m.sports.naver.com/esports/article/109...
#
#                                            description  \
# 0    4월과 함께 e스포츠 업계를 달구고 있는 젠지 '리그오브레전드' 프로게이머 <b>룰...
# 1    탈세 논란을 받는 프로게이머 <b>룰러</b> 박재혁 선수 이슈가 계속되는 가운데 ...
# 2    '<b>룰러</b>'의 잘못은 잘못이다. 개인의 사안은 절차에 따라 LCK 사무국이...
# 3    수세에서 공세로 나선 디플러스 기아는 34분경 드래곤 지역에서 집요하게 '<b>룰러...
# 4    젠지는 ‘조세 회피’ 와 관련된 ‘<b>룰러</b>’의 문제가 서서히 드러나고 있다...
# ..                                                 ...
# 995  <b>룰러</b>: 플레이오프 시작전 마지막 경기였는데 경기력이 잘 나와서 기분이 ...
# 996  '<b>룰러</b>' 박재혁도 &quot;플레이오프를 앞두고 잘 할 수 있는 경기를...
# 997  라이너 ‘<b>룰러</b>’ 박재혁 선수가 경기 후 인터뷰에 참석했다. 김정수 감독...
# 998  ‘<b>룰러</b>’ 박재혁은 이날 젠지의 승리 주역이었다. 2세트 제리, 3세트 ...
# 999  2세트 펜타킬을 터뜨린 ‘<b>룰러</b>’ 박재혁과 미드 2번째 500승 고지와 ...
#
#                              pubDate
# 0    Tue, 14 Apr 2026 11:38:00 +0900
# 1    Tue, 14 Apr 2026 11:32:00 +0900
# 2    Tue, 14 Apr 2026 10:00:00 +0900
# 3    Mon, 13 Apr 2026 14:56:00 +0900
# 4    Mon, 13 Apr 2026 13:50:00 +0900
# ..                               ...
# 995  Sat, 30 Aug 2025 18:56:00 +0900
# 996  Sat, 30 Aug 2025 18:38:00 +0900
# 997  Sat, 30 Aug 2025 18:24:00 +0900
# 998  Sat, 30 Aug 2025 18:20:00 +0900
# 999  Sat, 30 Aug 2025 18:00:00 +0900
#
# [1000 rows x 5 columns]
